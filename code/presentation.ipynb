# %% [markdown]
# <h1 style="text-align: center;">Notebook for Presentation Figs</h1>

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm

import data_analysis
import importlib
importlib.reload(data_analysis)

import utils
importlib.reload(utils)

# %matplotlib inline
matplotlib.pyplot.rc('text', usetex=True)

fontsize = 18

# %%
from data_analysis import Simulation


Lambda = 1e-2
Ra = 1e8
pandey = False


simulation = Simulation("../", Lambda=Lambda, Ra=Ra, pandey=pandey)
time, x, z, u, w, T, umean, wmean, Tmean = simulation.import_data(mean_type="scaled")
print(simulation.m)
# Out:
# data from ..//data/bulk_L0.01_Ra8.npz
# X shape (6249, 12393)
# 6249

# %%
simulation.plot_field(1376)

# %%
# simulation.save_clip(1350, 1400, '../presentation/page_presentation/')
# from data_analysis import make_gif
make_gif('../presentation/page_presentation/', '../presentation/page_presentation.gif', 5)
# Out:
# GIF created at: ../presentation/page_presentation.gif

# %%
import os
from natsort import natsorted
import imageio
def make_movie(image_directory, movie_path, fps):
    # Get all image files in the directory
    image_files = natsorted([os.path.join(image_directory, file) for file in os.listdir(image_directory) if file.endswith('.png')])

    # Open the first image to get the size
    first_image = imageio.imread(image_files[0])
    height, width, _ = first_image.shape

    # Create a video writer object
    writer = imageio.get_writer(movie_path, fps=fps, codec='libx264')

    for image_file in image_files:
        image = imageio.imread(image_file)
        
        writer.append_data(image)
    
    writer.close()

# %%
make_movie('../presentation/page_presentation/', '../presentation/page_presentation.mp4', 10)
# Out:
# /tmp/ipykernel_1170279/3383185079.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   first_image = imageio.imread(image_files[0])
# /tmp/ipykernel_1170279/3383185079.py:16: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_file)
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (4470, 611) to (4480, 624) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ...
